# %%
from game_driver_pyppeteer import GameDriverPyppeteer as GDP
from time import sleep
from IPython.display import display

# %%
driver = GDP()
await driver.init_browser()
driver.navigate('https://mattmakesgames.itch.io/celesteclassic')
# driver.navigate('https://unixpapa.com/js/testkey.html')
# driver.navigate("https://sevencrane.itch.io/vapor-trails")

sleep(5)

display(await driver.screenshot("game_drop"))

sleep(1)

del driver
# Out:
# game driver closed
